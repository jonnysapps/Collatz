# %% [markdown]
# # Observing The Collatz Conjecture

# %% [markdown]
# Below is a piece of code which prints the integer values between 1 and *n*:

# %%
def Func(x):
    return x + 1

n = 5
x = 0
while x < n:
    x = Func(x)
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Below two more numerical functions are defined:

# %%
def Func2(x):
    return x//2

def Func3(x):
    return (3*x)+1

# %% [markdown]
# We will now write a similar piece of code to where we printed the integers between 1 and *n* but this time we are going to apply Func2/3 depending on whether *n* is even or odd respectively, stopping only if *n* is 1:

# %%
n = 130
steps = 0
print(n)

while n != 1:
    if n % 2 == 0:
        n = Func2(n)
        print(n)
        steps = steps + 1
            
    else:
        n = Func3(n)
        print(n)
        steps = steps + 1
# Out:
# 130
# 65
# 196
# 98
# 49
# 148
# 74
# 37
# 112
# 56
# 28
# 14
# 7
# 22
# 11
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# What we have above is a demonstration of one of the great unsolved mathematematical mysteries, the Collatz conjecture. It deems that as long as *n* is a positive integer the above code will always eventually get to 1 without entering any loops. No proof has ever been published so there my be a number which does not abide by these rules, none have yet been found.
#
# The next thing we can look at is how the total number of iterations to reach 1 varies with *n*. This is done below:

# %%
import pandas as pd

steps = 0
List = []
for n in range(1,200):
    num = n
    while n != 1:
        if n % 2 == 0:
            n = Func2(n)
            steps = steps + 1
            
        else:
            n = Func3(n)
            steps = steps + 1
    List.append([num,steps])
    steps = 0

print(List)

#plot results
# %matplotlib inline

df = pd.DataFrame(List)
df.columns = ['n','Steps']

#print(df)

ax = df.plot(y = "Steps", x = "n")
ax.set_ylabel("Steps to reach 1")
# Out:
# [[1, 0], [2, 1], [3, 7], [4, 2], [5, 5], [6, 8], [7, 16], [8, 3], [9, 19], [10, 6], [11, 14], [12, 9], [13, 9], [14, 17], [15, 17], [16, 4], [17, 12], [18, 20], [19, 20], [20, 7], [21, 7], [22, 15], [23, 15], [24, 10], [25, 23], [26, 10], [27, 111], [28, 18], [29, 18], [30, 18], [31, 106], [32, 5], [33, 26], [34, 13], [35, 13], [36, 21], [37, 21], [38, 21], [39, 34], [40, 8], [41, 109], [42, 8], [43, 29], [44, 16], [45, 16], [46, 16], [47, 104], [48, 11], [49, 24], [50, 24], [51, 24], [52, 11], [53, 11], [54, 112], [55, 112], [56, 19], [57, 32], [58, 19], [59, 32], [60, 19], [61, 19], [62, 107], [63, 107], [64, 6], [65, 27], [66, 27], [67, 27], [68, 14], [69, 14], [70, 14], [71, 102], [72, 22], [73, 115], [74, 22], [75, 14], [76, 22], [77, 22], [78, 35], [79, 35], [80, 9], [81, 22], [82, 110], [83, 110], [84, 9], [85, 9], [86, 30], [87, 30], [88, 17], [89, 30], [90, 17], [91, 92], [92, 17], [93, 17], [94, 105], [95, 105], [96, 12], [97, 118], [98, 25], [99, 25], [100, 25], [101, 25], [102, 25], [103, 87], [104, 12], [105, 38], [106, 12], [107, 100], [108, 113], [109, 113], [110, 113], [111, 69], [112, 20], [113, 12], [114, 33], [115, 33], [116, 20], [117, 20], [118, 33], [119, 33], [120, 20], [121, 95], [122, 20], [123, 46], [124, 108], [125, 108], [126, 108], [127, 46], [128, 7], [129, 121], [130, 28], [131, 28], [132, 28], [133, 28], [134, 28], [135, 41], [136, 15], [137, 90], [138, 15], [139, 41], [140, 15], [141, 15], [142, 103], [143, 103], [144, 23], [145, 116], [146, 116], [147, 116], [148, 23], [149, 23], [150, 15], [151, 15], [152, 23], [153, 36], [154, 23], [155, 85], [156, 36], [157, 36], [158, 36], [159, 54], [160, 10], [161, 98], [162, 23], [163, 23], [164, 111], [165, 111], [166, 111], [167, 67], [168, 10], [169, 49], [170, 10], [171, 124], [172, 31], [173, 31], [174, 31], [175, 80], [176, 18], [177, 31], [178, 31], [179, 31], [180, 18], [181, 18], [182, 93], [183, 93], [184, 18], [185, 44], [186, 18], [187, 44], [188, 106], [189, 106], [190, 106], [191, 44], [192, 13], [193, 119], [194, 119], [195, 119], [196, 26], [197, 26], [198, 26], [199, 119]]
# Text(0, 0.5, 'Steps to reach 1')

# %% [markdown]
# It can be seen above that there is almost no patterns or trends to be drawn from the data.
#
# Lets look at the top *steps* values and their corresponding *n* values to see if there is any relation between these numbers:

# %%
df = df.sort_values('Steps', ascending = False)

print(df.head(10))
# Out:
#        n  Steps
# 170  171    124
# 128  129    121
# 198  199    119
# 194  195    119
# 193  194    119
# 192  193    119
# 96    97    118
# 144  145    116
# 146  147    116
# 145  146    116

# %% [markdown]
# Once again this sheds very little light as the *n* values are a mixture of odd/even/prime/3-digit and 2-digit numbers. It can be noted that consecutive numbers can often yield the same result, but this could also been see from the above graph.
#
# It could possibly be useful to see how *n* varies with step number for specific numbers of of interest. This can be found below:

# %%
n = 129
steps = 0
List2 = []
List2.append([steps,n])

while n != 1:
    if n % 2 == 0:
        n = Func2(n)
        steps = steps + 1
        List2.append([steps,n])
            
    else:
        n = Func3(n)
        steps = steps + 1
        List2.append([steps,n])

print(List2)

# %matplotlib inline

df = pd.DataFrame(List2)
df.columns = ['Step','n']

ax = df.plot(y = "n", x = "Step")
ax.set_ylabel("n")
# Out:
# [[0, 129], [1, 388], [2, 194], [3, 97], [4, 292], [5, 146], [6, 73], [7, 220], [8, 110], [9, 55], [10, 166], [11, 83], [12, 250], [13, 125], [14, 376], [15, 188], [16, 94], [17, 47], [18, 142], [19, 71], [20, 214], [21, 107], [22, 322], [23, 161], [24, 484], [25, 242], [26, 121], [27, 364], [28, 182], [29, 91], [30, 274], [31, 137], [32, 412], [33, 206], [34, 103], [35, 310], [36, 155], [37, 466], [38, 233], [39, 700], [40, 350], [41, 175], [42, 526], [43, 263], [44, 790], [45, 395], [46, 1186], [47, 593], [48, 1780], [49, 890], [50, 445], [51, 1336], [52, 668], [53, 334], [54, 167], [55, 502], [56, 251], [57, 754], [58, 377], [59, 1132], [60, 566], [61, 283], [62, 850], [63, 425], [64, 1276], [65, 638], [66, 319], [67, 958], [68, 479], [69, 1438], [70, 719], [71, 2158], [72, 1079], [73, 3238], [74, 1619], [75, 4858], [76, 2429], [77, 7288], [78, 3644], [79, 1822], [80, 911], [81, 2734], [82, 1367], [83, 4102], [84, 2051], [85, 6154], [86, 3077], [87, 9232], [88, 4616], [89, 2308], [90, 1154], [91, 577], [92, 1732], [93, 866], [94, 433], [95, 1300], [96, 650], [97, 325], [98, 976], [99, 488], [100, 244], [101, 122], [102, 61], [103, 184], [104, 92], [105, 46], [106, 23], [107, 70], [108, 35], [109, 106], [110, 53], [111, 160], [112, 80], [113, 40], [114, 20], [115, 10], [116, 5], [117, 16], [118, 8], [119, 4], [120, 2], [121, 1]]
# Text(0, 0.5, 'n')
